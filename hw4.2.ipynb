# %%
import pandas as pd #함수 불러오기

# %%
#1차원 배열
s = pd.Series([1, 3, 5, 7, 9])
print(s)
print(s[2]) #indexing
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
# 5

# %%
# dictionary를 이용해 만들기
dic = {'a':1, 'b':3, 'c':5}
s = pd.Series(dic)
print(s)
print(s['b']) #indexing
# Out:
# a    1
# b    3
# c    5
# dtype: int64
# 3

# %%
#출력
print(s.values)
print(s.index)
# Out:
# [1 3 5]
# Index(['a', 'b', 'c'], dtype='object')

# %%
# 1차원 배열
s = pd.Series([1,3,5,7,9], index=['LGT','DOO','HWE','LOT','SKW'])
#print(s)
#print(s['LOT'])
print(s[:'LOT']) # 슬라이싱에서 어디까지 나오는지 주목
# Out:
# LGT    1
# DOO    3
# HWE    5
# LOT    7
# dtype: int64

# %%
# 데이터 프레임 생성
score={'학번':[201524213,201621223,201621233],
       '이름':['오지환','박용택','정성훈'],
       'Quiz':[15,20,10],
       '중간고사':[20,20,15]}

score_df= pd.DataFrame(score)
score_df
# Out:
#           학번   이름  Quiz  중간고사
# 0  201524213  오지환    15    20
# 1  201621223  박용택    20    20
# 2  201621233  정성훈    10    15

# %%
print(type(score_df['학번'])) #출력
score_df['학번']
# Out:
# <class 'pandas.core.series.Series'>
# 0    201524213
# 1    201621223
# 2    201621233
# Name: 학번, dtype: int64

# %%
# 데이터 프레임 생성
d = {
    'Name':['Alisa','Bobby','Cathrine','Madonna','Rocky','Sebastian','Jaqluine',
   'Rahul','David','Andrew','Ajay','Teresa'],
   'Age':[26,27,25,24,31,27,25,33,42,32,51,47],
   'Score':[89,87,67,55,47,72,76,79,44,92,99,69]}
 
df = pd.DataFrame(d)
df
# Out:
#          Name  Age  Score
# 0       Alisa   26     89
# 1       Bobby   27     87
# 2    Cathrine   25     67
# 3     Madonna   24     55
# 4       Rocky   31     47
# 5   Sebastian   27     72
# 6    Jaqluine   25     76
# 7       Rahul   33     79
# 8       David   42     44
# 9      Andrew   32     92
# 10       Ajay   51     99
# 11     Teresa   47     69

# %%
df['Age'] # 나이만 출력
# Out:
# 0     26
# 1     27
# 2     25
# 3     24
# 4     31
# 5     27
# 6     25
# 7     33
# 8     42
# 9     32
# 10    51
# 11    47
# Name: Age, dtype: int64

# %%
df[['Name', 'Age']] #이름과 나이 출력
# Out:
#          Name  Age
# 0       Alisa   26
# 1       Bobby   27
# 2    Cathrine   25
# 3     Madonna   24
# 4       Rocky   31
# 5   Sebastian   27
# 6    Jaqluine   25
# 7       Rahul   33
# 8       David   42
# 9      Andrew   32
# 10       Ajay   51
# 11     Teresa   47

# %%
type(df['Name']) # [] 한개 쓰면 시리즈
# Out:
# pandas.core.series.Series

# %%
type(df[['Name']]) #[] 두개 쓰면 데이터프레임
# Out:
# pandas.core.frame.DataFrame

# %%
df[0:3]  #df[2]는 에러 발생
# Out:
#        Name  Age  Score
# 0     Alisa   26     89
# 1     Bobby   27     87
# 2  Cathrine   25     67

# %%
df=df.reindex([1,4,6,2,3,5,9,8,0,7,11,10]) # 일부러 순차가 아닌 인덱스를 부여
df
# Out:
#          Name  Age  Score
# 1       Bobby   27     87
# 4       Rocky   31     47
# 6    Jaqluine   25     76
# 2    Cathrine   25     67
# 3     Madonna   24     55
# 5   Sebastian   27     72
# 9      Andrew   32     92
# 8       David   42     44
# 0       Alisa   26     89
# 7       Rahul   33     79
# 11     Teresa   47     69
# 10       Ajay   51     99

# %%
df.loc[:6] #6까지 출력
# Out:
#        Name  Age  Score
# 1     Bobby   27     87
# 4     Rocky   31     47
# 6  Jaqluine   25     76

# %%
df.iloc[:6] #6개 출력
# Out:
#         Name  Age  Score
# 1      Bobby   27     87
# 4      Rocky   31     47
# 6   Jaqluine   25     76
# 2   Cathrine   25     67
# 3    Madonna   24     55
# 5  Sebastian   27     72

# %%
# 순차적 출력
 
df1=df.sort_index()
df1
# Out:
#          Name  Age  Score
# 0       Alisa   26     89
# 1       Bobby   27     87
# 2    Cathrine   25     67
# 3     Madonna   24     55
# 4       Rocky   31     47
# 5   Sebastian   27     72
# 6    Jaqluine   25     76
# 7       Rahul   33     79
# 8       David   42     44
# 9      Andrew   32     92
# 10       Ajay   51     99
# 11     Teresa   47     69

# %%
df1.loc[:6] #6까지 출력
# Out:
#         Name  Age  Score
# 0      Alisa   26     89
# 1      Bobby   27     87
# 2   Cathrine   25     67
# 3    Madonna   24     55
# 4      Rocky   31     47
# 5  Sebastian   27     72
# 6   Jaqluine   25     76

# %%
df1.iloc[:6] # 6개 출력
# Out:
#         Name  Age  Score
# 0      Alisa   26     89
# 1      Bobby   27     87
# 2   Cathrine   25     67
# 3    Madonna   24     55
# 4      Rocky   31     47
# 5  Sebastian   27     72

# %%
# 내림차순으로 출력
 
df2=df.sort_index(ascending=False)
df2
# Out:
#          Name  Age  Score
# 11     Teresa   47     69
# 10       Ajay   51     99
# 9      Andrew   32     92
# 8       David   42     44
# 7       Rahul   33     79
# 6    Jaqluine   25     76
# 5   Sebastian   27     72
# 4       Rocky   31     47
# 3     Madonna   24     55
# 2    Cathrine   25     67
# 1       Bobby   27     87
# 0       Alisa   26     89

# %%
df2.iloc[:, 2] # 두 열 출력하기
# Out:
# 11    69
# 10    99
# 9     92
# 8     44
# 7     79
# 6     76
# 5     72
# 4     47
# 3     55
# 2     67
# 1     87
# 0     89
# Name: Score, dtype: int64

# %%
df2.loc[:, ['Name', 'Age']] # 이름과 나이열 출력
# Out:
#          Name  Age
# 11     Teresa   47
# 10       Ajay   51
# 9      Andrew   32
# 8       David   42
# 7       Rahul   33
# 6    Jaqluine   25
# 5   Sebastian   27
# 4       Rocky   31
# 3     Madonna   24
# 2    Cathrine   25
# 1       Bobby   27
# 0       Alisa   26

# %%
df2.iloc[:, :2]
# Out:
#          Name  Age
# 11     Teresa   47
# 10       Ajay   51
# 9      Andrew   32
# 8       David   42
# 7       Rahul   33
# 6    Jaqluine   25
# 5   Sebastian   27
# 4       Rocky   31
# 3     Madonna   24
# 2    Cathrine   25
# 1       Bobby   27
# 0       Alisa   26

# %%
df2.loc[:, :'Age'] # 나이 열 까지 출력
# Out:
#          Name  Age
# 11     Teresa   47
# 10       Ajay   51
# 9      Andrew   32
# 8       David   42
# 7       Rahul   33
# 6    Jaqluine   25
# 5   Sebastian   27
# 4       Rocky   31
# 3     Madonna   24
# 2    Cathrine   25
# 1       Bobby   27
# 0       Alisa   26

# %%
df = pd.read_csv('Churn.csv', encoding = 'cp949') #데이터 불러오기

# %%
df.head() #상위 5개 추출
# Out:
#       고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수   주간통화시간_분  야간통화횟수   야간통화시간_분  \
# 0  C101180  남  37.0  20.333333   1.0    29.0  46.800000    17.0  47.400000
# 1  C101300  남  38.0  35.000000   1.0    25.0  33.024909    20.0  19.814945
# 2  C101770  남  30.0  17.500000   0.0     2.0  67.800000     6.0  30.600000
# 3  C101780  남  33.0  25.966667   0.0    10.0  52.200001    48.0  90.300001
# 4  C101800  남  40.0  51.466667   2.0     7.0  25.008754    24.0  39.726294
#
#    주말통화횟수   주말통화시간_분   국제통화시간_분  국내통화횟수    국내통화시간_분     총통화시간_분 통화량구분  \
# 0     3.0  30.000000  14.555928    49.0  124.200000  138.755928     저
# 1     2.0  37.218548  12.091963    47.0   90.058402  102.150365     저
# 2     8.0  75.000000  42.715277    16.0  173.400000  216.115277     저
# 3    12.0  19.500000  19.299243    70.0  162.000002  181.299245     저
# 4     2.0   2.950885   1.413106    33.0   67.685933   69.099039     저
#
#        총통화요금       부과요금 통화품질불만 이탈여부
# 0   5.822371  65.762371      F   이탈
# ...

# %%
df.shape # 행과 열의 개수 파악
# Out:
# (9565, 20)

# %%
df.columns.tolist() #열의 이름을 리스트로 반환
# Out:
# ['고객ID',
#  '성별',
#  '연령',
#  '서비스기간',
#  '단선횟수',
#  '주간통화횟수',
#  '주간통화시간_분',
#  '야간통화횟수',
#  '야간통화시간_분',
#  '주말통화횟수',
#  '주말통화시간_분',
#  '국제통화시간_분',
#  '국내통화횟수',
#  '국내통화시간_분',
#  '총통화시간_분',
#  '통화량구분',
#  '총통화요금',
#  '부과요금',
#  '통화품질불만',
#  '이탈여부']

# %%
df.describe() #다양한 통계 확인
# Out:
#                 연령        서비스기간         단선횟수       주간통화횟수     주간통화시간_분  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     37.539000    34.303800     2.588000   416.383000   924.028034
# std       9.967137    13.718647     3.319529   295.198612   456.232080
# min      13.000000     9.666667     0.000000     0.000000     0.000000
# 25%      30.000000    22.866667     1.000000   177.750000   605.999999
# 50%      35.000000    34.633333     1.000000   372.500000   848.100001
# 75%      44.000000    46.200000     2.000000   581.000000  1150.350000
# max      71.000000    58.200000    15.000000  1581.000000  2846.399999
#
#             야간통화횟수     야간통화시간_분       주말통화횟수     주말통화시간_분     국제통화시간_분  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     96.501000   272.809041    15.918000    49.733469   290.577775
# std      90.697376   171.499299    16.410197    36.612601   124.608438
# ...

# %%
df.max() #열들의 최댓값
# Out:
# 연령            71.000000
# 서비스기간         58.200000
# 단선횟수          15.000000
# 주간통화횟수      1581.000000
# 주간통화시간_분    2846.399999
# 야간통화횟수       500.000000
# 야간통화시간_분     883.800000
# 주말통화횟수        92.000000
# 주말통화시간_분     195.499999
# 국제통화시간_분     892.557103
# 국내통화횟수      1802.000000
# 국내통화시간_분    3192.900003
# 총통화시간_분     3899.818410
# 총통화요금        410.308935
# 부과요금         560.308935
# dtype: float64

# %%
df['주간통화횟수'].max() #특정열의 최댓값
# Out:
# 1581.0

# %%
df['야간통화횟수'].mean() # 야간통화횟수의 평균
# Out:
# 96.501

# %%
df['주간통화횟수'].argmax() #주간통화횟수가 최대인 행의 위치 파악
# Out:
# 304

# %%
df.loc[304] #반환된 index 값을 이용해 값을 출력
# Out:
# 고객ID        C111730
# 성별                남
# 연령               48
# 서비스기간       34.7333
# 단선횟수              1
# 주간통화횟수         1581
# 주간통화시간_분       2430
# 야간통화횟수          151
# 야간통화시간_분      278.1
# 주말통화횟수           70
# 주말통화시간_분        117
# 국제통화시간_분    482.942
# 국내통화횟수         1802
# 국내통화시간_분     2825.1
# 총통화시간_분     3308.04
# 통화량구분             고
# 총통화요금       296.029
# 부과요금        446.029
# 통화품질불만            F
# 이탈여부             유지
# Name: 304, dtype: object

# %%
df.loc[df['주간통화횟수'].idxmax()] #위 과정을 하나로 합침
# Out:
# 고객ID        C111730
# 성별                남
# 연령               48
# 서비스기간       34.7333
# 단선횟수              1
# 주간통화횟수         1581
# 주간통화시간_분       2430
# 야간통화횟수          151
# 야간통화시간_분      278.1
# 주말통화횟수           70
# 주말통화시간_분        117
# 국제통화시간_분    482.942
# 국내통화횟수         1802
# 국내통화시간_분     2825.1
# 총통화시간_분     3308.04
# 통화량구분             고
# 총통화요금       296.029
# 부과요금        446.029
# 통화품질불만            F
# 이탈여부             유지
# Name: 304, dtype: object

# %%
df['통화량구분'].value_counts() #통화량구분에 따른 횟수
# Out:
# 중     575
# 중고    294
# 고      90
# 중저     34
# 저       7
# Name: 통화량구분, dtype: int64

# %%
daytime = df['주간통화횟수']
daytime.head() #갯수가 너무 많으므로 뒤에 head()함수를 써서 앞부분만 추출
# Out:
# 0    29.0
# 1    25.0
# 2     2.0
# 3    10.0
# 4     7.0
# Name: 주간통화횟수, dtype: float64

# %%
df.loc[[df['주간통화횟수'].idxmax()]]
# Out:
#         고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수  주간통화시간_분  야간통화횟수    야간통화시간_분  \
# 304  C111730  남  48.0  34.733333   1.0  1581.0    2430.0   151.0  278.100001
#
#      주말통화횟수  주말통화시간_분    국제통화시간_분  국내통화횟수     국내통화시간_분      총통화시간_분 통화량구분  \
# 304    70.0     117.0  482.942341  1802.0  2825.100001  3308.042342     고
#
#          총통화요금       부과요금 통화품질불만 이탈여부
# 304  296.02891  446.02891      F   유지

# %%
df.loc[df['주간통화횟수'].idxmax()] # []를 몇개 쓰냐에 따라 보여주는 방식이 달라짐
# Out:
# 고객ID        C111730
# 성별                남
# 연령               48
# 서비스기간       34.7333
# 단선횟수              1
# 주간통화횟수         1581
# 주간통화시간_분       2430
# 야간통화횟수          151
# 야간통화시간_분      278.1
# 주말통화횟수           70
# 주말통화시간_분        117
# 국제통화시간_분    482.942
# 국내통화횟수         1802
# 국내통화시간_분     2825.1
# 총통화시간_분     3308.04
# 통화량구분             고
# 총통화요금       296.029
# 부과요금        446.029
# 통화품질불만            F
# 이탈여부             유지
# Name: 304, dtype: object

# %%
df.loc[[df['주간통화횟수'].idxmax()]]['야간통화횟수'] # 국제통화시간 분이 많은 고객
# Out:
# 304    151.0
# Name: 야간통화횟수, dtype: float64

# %%
df.loc[df['주간통화횟수'].idxmax()]['야간통화횟수']
# Out:
# 151.0

# %%
df.loc[df['주간통화횟수'].idxmax(), '야간통화횟수'] # 다양하게 표현가능
# Out:
# 151.0

# %%
type(df.loc[[df['주간통화횟수'].idxmax()]]['야간통화횟수'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc[[df['주간통화횟수'].idxmax()]]) #타입 확인
# Out:
# pandas.core.frame.DataFrame

# %%
df.sort_values('야간통화횟수').head() # 야간통화횟수에 따라 오름차순으로 다섯개 출력
# Out:
#         고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수  주간통화시간_분  야간통화횟수  야간통화시간_분  \
# 41   C104020  여  28.0  51.800000   0.0   312.0     727.8     0.0       0.0
# 600  C119020  남  29.0  45.800000   1.0   725.0    1179.0     0.0       0.0
# 594  C118930  남  30.0  44.266667   2.0   405.0     912.0     0.0       0.0
# 585  C118590  여  58.0  55.633333   1.0   887.0    1587.0     0.0       0.0
# 682  C123670  남  30.0  51.633333   0.0   393.0     967.2     0.0       0.0
#
#      주말통화횟수    주말통화시간_분    국제통화시간_분  국내통화횟수     국내통화시간_분      총통화시간_분 통화량구분  \
# 41      4.0   28.800000  294.653878   316.0   756.600000  1051.253878     중
# 600    66.0  167.500002  183.864556   791.0  1346.500002  1530.364558    중고
# 594    41.0   98.400000  343.663560   446.0  1010.400000  1354.063560     중
# 585    91.0  143.400000  296.243918   978.0  1730.400000  2026.643918    중고
# 682     1.0   24.500000  187.697977   394.0   991.700000  1179.397977     중
#
#           총통화요금        부과요금 통화품질불만 이탈여부
# ...

# %%
print(type(df['주간통화횟수'] > 7)) # True/False 시리즈로 반환되는지 확인
(df['주간통화횟수'] > 7).head() # 시리즈의 앞부분을 확인
# Out:
# <class 'pandas.core.series.Series'>
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: 주간통화횟수, dtype: bool

# %%
df[df['주간통화횟수'] > 7].head() # Boolean Series를 이용해 조건이 True인 행들만 추출
# Out:
#       고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수    주간통화시간_분  야간통화횟수    야간통화시간_분  \
# 0  C101180  남  37.0  20.333333   1.0    29.0   46.800000    17.0   47.400000
# 1  C101300  남  38.0  35.000000   1.0    25.0   33.024909    20.0   19.814945
# 3  C101780  남  33.0  25.966667   0.0    10.0   52.200001    48.0   90.300001
# 7  C102600  여  45.0  24.700000   2.0   234.0  522.000000   185.0  299.100001
# 8  C102610  여  34.0  24.866667   2.0   337.0  580.800000    11.0   92.400000
#
#    주말통화횟수   주말통화시간_분    국제통화시간_분  국내통화횟수    국내통화시간_분      총통화시간_분 통화량구분  \
# 0     3.0  30.000000   14.555928    49.0  124.200000   138.755928     저
# 1     2.0  37.218548   12.091963    47.0   90.058402   102.150365     저
# 3    12.0  19.500000   19.299243    70.0  162.000002   181.299245     저
# 7    46.0  97.800000  257.307962   465.0  918.900001  1176.207963     중
# 8    29.0  61.800000  216.893750   377.0  735.000000   951.893750     중
#
#         총통화요금        부과요금 통화품질불만 이탈여부
# ...

# %%
df[(df['주간통화횟수'] > 800) & (df['야간통화횟수'] < 200)] # 주간통화횟수 800초과, 야간통화횟수 200미만 행 출력
# Out:
#         고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수     주간통화시간_분  야간통화횟수  \
# 281  C111340  여  45.0  28.633333   5.0   910.0  1398.600000    28.0
# 291  C111510  남  27.0  45.000000   1.0   895.0  1834.199999    28.0
# 295  C111570  남  42.0  54.300000   2.0  1399.0  2412.000000    53.0
# 302  C111680  여  38.0  51.066667   0.0  1179.0  1992.600000    12.0
# 304  C111730  남  48.0  34.733333   1.0  1581.0  2430.000000   151.0
# ..       ... ..   ...        ...   ...     ...          ...     ...
# 764  C126240  여  36.0  19.000000   2.0   861.0  1434.000000    12.0
# 771  C126410  여  32.0  17.566667   1.0  1005.0  1672.800001    54.0
# 773  C126450  여  28.0  27.166667   2.0   987.0  1548.600000   119.0
# 798  C128680  남  27.0  13.300000   6.0  1482.0  2846.399999    28.0
# 811  C129220  여  35.0  35.266667   1.0   997.0  2728.199999   179.0
#
#        야간통화시간_분  주말통화횟수    주말통화시간_분    국제통화시간_분  국내통화횟수     국내통화시간_분  \
# 281  171.000000     7.0   30.600000  460.589198   945.0  1600.200000
# ...

# %%
df.groupby('통화량구분')['주간통화횟수'].mean().head() #통화량 구분에 따른 주간통화횟수 평균
# Out:
# 통화량구분
# 고     957.688889
# 저      12.000000
# 중     254.904348
# 중고    617.676871
# 중저     57.058824
# Name: 주간통화횟수, dtype: float64

# %%
df.groupby('통화량구분')['이탈여부'].value_counts().head(9) #통화량에 따라 이탈여부 확인
# Out:
# 통화량구분  이탈여부
# 고      유지       62
#        이탈       28
# 저      이탈        7
# 중      유지      413
#        이탈      162
# 중고     유지      212
#        이탈       82
# 중저     이탈       21
#        유지       13
# Name: 이탈여부, dtype: int64

# %%
# 데이터프레임의 값들 Numpy 형태로 반환
print(type(df.values))
print(df.values.shape)
df.values
# Out:
# <class 'numpy.ndarray'>
# (9565, 20)
# array([['C101180', '남', 37.0, ..., 65.762371, 'F', '이탈'],
#        ['C101300', '남', 38.0, ..., 64.776785, 'F', '이탈'],
#        ['C101770', '남', 30.0, ..., 77.026111, 'F', '이탈'],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
df.values[0, 0] # 데이터프레임의 값들 Numpy 형태로 반환
# Out:
# 'C101180'

# %%
#데이터프레임 행 단위로 순환
for index, row in df.iterrows():
    print('#Data type of row:', type(row))
    print(row)
    if index == 1:
        break
# Out:
# #Data type of row: <class 'pandas.core.series.Series'>
# 고객ID        C101180
# 성별                남
# 연령               37
# 서비스기간       20.3333
# 단선횟수              1
# 주간통화횟수           29
# 주간통화시간_분       46.8
# 야간통화횟수           17
# 야간통화시간_분       47.4
# 주말통화횟수            3
# 주말통화시간_분         30
# 국제통화시간_분    14.5559
# 국내통화횟수           49
# 국내통화시간_분      124.2
# 총통화시간_분     138.756
# 통화량구분             저
# 총통화요금       5.82237
# 부과요금        65.7624
# 통화품질불만            F
# 이탈여부             이탈
# Name: 0, dtype: object
# #Data type of row: <class 'pandas.core.series.Series'>
# 고객ID        C101300
# 성별                남
# 연령               38
# 서비스기간            35
# 단선횟수              1
# 주간통화횟수           25
# 주간통화시간_분    33.0249
# 야간통화횟수           20
# 야간통화시간_분    19.8149
# 주말통화횟수            2
# 주말통화시간_분    37.2185
# 국제통화시간_분     12.092
# 국내통화횟수           47
# 국내통화시간_분    90.0584
# 총통화시간_분      102.15
# 통화량구분             저
# 총통화요금       4.83678
# 부과요금        64.7768
# 통화품질불만            F
# ...

# %%
#데이터클리닝
df.isnull().sum()
# Out:
# 고객ID        8565
# 성별          8565
# 연령          8565
# 서비스기간       8565
# 단선횟수        8565
# 주간통화횟수      8565
# 주간통화시간_분    8565
# 야간통화횟수      8565
# 야간통화시간_분    8565
# 주말통화횟수      8565
# 주말통화시간_분    8565
# 국제통화시간_분    8565
# 국내통화횟수      8565
# 국내통화시간_분    8565
# 총통화시간_분     8565
# 통화량구분       8565
# 총통화요금       8565
# 부과요금        8565
# 통화품질불만      8565
# 이탈여부        8565
# dtype: int64

# %%
df1 = pd.read_csv('Churn.csv', encoding = 'cp949')
df1
# Out:
#          고객ID   성별    연령      서비스기간  단선횟수  주간통화횟수   주간통화시간_분  야간통화횟수  \
# 0     C101180    남  37.0  20.333333   1.0    29.0  46.800000    17.0
# 1     C101300    남  38.0  35.000000   1.0    25.0  33.024909    20.0
# 2     C101770    남  30.0  17.500000   0.0     2.0  67.800000     6.0
# 3     C101780    남  33.0  25.966667   0.0    10.0  52.200001    48.0
# 4     C101800    남  40.0  51.466667   2.0     7.0  25.008754    24.0
# ...       ...  ...   ...        ...   ...     ...        ...     ...
# 9560      NaN  NaN   NaN        NaN   NaN     NaN        NaN     NaN
# 9561      NaN  NaN   NaN        NaN   NaN     NaN        NaN     NaN
# 9562      NaN  NaN   NaN        NaN   NaN     NaN        NaN     NaN
# 9563      NaN  NaN   NaN        NaN   NaN     NaN        NaN     NaN
# 9564      NaN  NaN   NaN        NaN   NaN     NaN        NaN     NaN
#
#        야간통화시간_분  주말통화횟수   주말통화시간_분   국제통화시간_분  국내통화횟수    국내통화시간_분     총통화시간_분  \
# ...

# %%
df1.isnull().sum() # null개수 확인
# Out:
# 고객ID        8565
# 성별          8565
# 연령          8565
# 서비스기간       8565
# 단선횟수        8565
# 주간통화횟수      8565
# 주간통화시간_분    8565
# 야간통화횟수      8565
# 야간통화시간_분    8565
# 주말통화횟수      8565
# 주말통화시간_분    8565
# 국제통화시간_분    8565
# 국내통화횟수      8565
# 국내통화시간_분    8565
# 총통화시간_분     8565
# 통화량구분       8565
# 총통화요금       8565
# 부과요금        8565
# 통화품질불만      8565
# 이탈여부        8565
# dtype: int64

# %%
df1.fillna(0) #결측치 모두 0으로 대체
# Out:
#          고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수   주간통화시간_분  야간통화횟수   야간통화시간_분  \
# 0     C101180  남  37.0  20.333333   1.0    29.0  46.800000    17.0  47.400000
# 1     C101300  남  38.0  35.000000   1.0    25.0  33.024909    20.0  19.814945
# 2     C101770  남  30.0  17.500000   0.0     2.0  67.800000     6.0  30.600000
# 3     C101780  남  33.0  25.966667   0.0    10.0  52.200001    48.0  90.300001
# 4     C101800  남  40.0  51.466667   2.0     7.0  25.008754    24.0  39.726294
# ...       ... ..   ...        ...   ...     ...        ...     ...        ...
# 9560        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9561        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9562        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9563        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9564        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
#
# ...

# %%
df1.dropna() #결측치 모두 0으로 대체
# Out:
#         고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수    주간통화시간_분  야간통화횟수  \
# 0    C101180  남  37.0  20.333333   1.0    29.0   46.800000    17.0
# 1    C101300  남  38.0  35.000000   1.0    25.0   33.024909    20.0
# 2    C101770  남  30.0  17.500000   0.0     2.0   67.800000     6.0
# 3    C101780  남  33.0  25.966667   0.0    10.0   52.200001    48.0
# 4    C101800  남  40.0  51.466667   2.0     7.0   25.008754    24.0
# ..       ... ..   ...        ...   ...     ...         ...     ...
# 995  C177200  남  14.0  22.366667  13.0   211.0  369.600001    70.0
# 996  C177220  여  19.0  49.366667  13.0   376.0  664.800001   127.0
# 997  C177250  남  30.0  23.166667  12.0   145.0  312.000000   144.0
# 998  C177340  여  21.0  50.233333  14.0   301.0  465.600000    48.0
# 999  C177370  남  49.0  41.433333  13.0   222.0  494.400001    14.0
#
#        야간통화시간_분  주말통화횟수   주말통화시간_분    국제통화시간_분  국내통화횟수    국내통화시간_분  \
# 0     47.400000     3.0  30.000000   14.555928    49.0  124.200000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ax = df['주간통화횟수'].plot.hist(bins=20)
ax.set_xlabel('Points for call of daytime')
plt.show()

# %%
df1.fillna(0).to_csv('test.csv')
df2 = pd.read_csv('test.csv')
df2
# Out:
#       Unnamed: 0     고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수   주간통화시간_분  \
# 0              0  C101180  남  37.0  20.333333   1.0    29.0  46.800000
# 1              1  C101300  남  38.0  35.000000   1.0    25.0  33.024909
# 2              2  C101770  남  30.0  17.500000   0.0     2.0  67.800000
# 3              3  C101780  남  33.0  25.966667   0.0    10.0  52.200001
# 4              4  C101800  남  40.0  51.466667   2.0     7.0  25.008754
# ...          ...      ... ..   ...        ...   ...     ...        ...
# 9560        9560        0  0   0.0   0.000000   0.0     0.0   0.000000
# 9561        9561        0  0   0.0   0.000000   0.0     0.0   0.000000
# 9562        9562        0  0   0.0   0.000000   0.0     0.0   0.000000
# 9563        9563        0  0   0.0   0.000000   0.0     0.0   0.000000
# 9564        9564        0  0   0.0   0.000000   0.0     0.0   0.000000
#
#       야간통화횟수   야간통화시간_분  ...   주말통화시간_분   국제통화시간_분  국내통화횟수    국내통화시간_분  \
# ...

# %%
#첫째 방법
df1.fillna(0).to_csv('test.csv', index=False) #인덱스를 저장하지 않음
df2 = pd.read_csv('test.csv')
df2
# Out:
#          고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수   주간통화시간_분  야간통화횟수   야간통화시간_분  \
# 0     C101180  남  37.0  20.333333   1.0    29.0  46.800000    17.0  47.400000
# 1     C101300  남  38.0  35.000000   1.0    25.0  33.024909    20.0  19.814945
# 2     C101770  남  30.0  17.500000   0.0     2.0  67.800000     6.0  30.600000
# 3     C101780  남  33.0  25.966667   0.0    10.0  52.200001    48.0  90.300001
# 4     C101800  남  40.0  51.466667   2.0     7.0  25.008754    24.0  39.726294
# ...       ... ..   ...        ...   ...     ...        ...     ...        ...
# 9560        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9561        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9562        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9563        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9564        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
#
# ...

# %%
#둘째 방법
df1.fillna(0).to_csv('test.csv')
df2 = pd.read_csv('test.csv', index_col=0) #첫 열을 인덱스로 저장
df2
# Out:
#          고객ID 성별    연령      서비스기간  단선횟수  주간통화횟수   주간통화시간_분  야간통화횟수   야간통화시간_분  \
# 0     C101180  남  37.0  20.333333   1.0    29.0  46.800000    17.0  47.400000
# 1     C101300  남  38.0  35.000000   1.0    25.0  33.024909    20.0  19.814945
# 2     C101770  남  30.0  17.500000   0.0     2.0  67.800000     6.0  30.600000
# 3     C101780  남  33.0  25.966667   0.0    10.0  52.200001    48.0  90.300001
# 4     C101800  남  40.0  51.466667   2.0     7.0  25.008754    24.0  39.726294
# ...       ... ..   ...        ...   ...     ...        ...     ...        ...
# 9560        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9561        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9562        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9563        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
# 9564        0  0   0.0   0.000000   0.0     0.0   0.000000     0.0   0.000000
#
# ...
